# %% [markdown]
# # Пособие по Augmentation/

# %% [markdown]
# ## Использование LookGenerator.config.config

# %%
import os
import numpy as np

from LookGenerator.config.config import DatasetConfig

Config = DatasetConfig(os.environ)
None

# %%
Config.show_details()
# Out:
# DATASET_DIR
# BACKGROUND_DATASET

# %% [markdown]
# ## Класс датасет для работы с файлами

# %%
from LookGenerator.datasets.background_cut_dataset import PersonDataset

# %%
person_dataset =  PersonDataset(Config.DATASET_DIR, "image", "image-parse-v3",
                                background_root_dir=r"D:\GenshinImpact\Genshin Impact game", # or use #Config.BACKGROUND_DATASET
                                dir_name_background="ScreenShot")

# %% [markdown]
# ## Импорт изображений человека, маски и фона

# %%
from torchvision.transforms import ToPILImage
import matplotlib.pyplot as plt
import math

def _print(image, mask):
    fig = plt.figure(figsize=(20, 14))

    fig.add_subplot( 1, 2, 1)
    plt.imshow(ToPILImage()(image))

    fig.add_subplot( 1, 2, 2)
    plt.imshow(mask[0])

# %%
image, mask = person_dataset.__getitem__(0)

# %%
_print(image, mask)

# %% [markdown]
# # Аугментация
